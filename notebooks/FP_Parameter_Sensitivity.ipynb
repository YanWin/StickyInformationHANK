# %% [markdown]
# Notebook to investigate how the IRFs change with different parameter values

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

import os
import datetime
import sys
import numpy as np
import pandas as pd
from copy import deepcopy

from HANKStickyModel import HANKStickyModelClass
from HANKStickyAnalytics import HANKStickyAnalyticsClass

# %% [markdown]
# # Settings

# %%
# settings

# save
save_models = False

# paths
path_savefolder = os.path.normpath(os.getcwd() + os.sep + os.pardir + os.sep + 'saved_models')  # save folder for models
path_images = os.path.normpath(os.getcwd() + os.sep + os.pardir + os.sep + 'images' + os.sep + 'parameter_sensitivity') # save folder for images

# model settings
baseline_inattention = 0.935 # baseline setting for inattention

shock_baseline = {'jump_eg': 0.0001,
                  'rho_eg': 0.7,
                  'jump_em': 0.0}

updated_par_base = {**{'inattention': baseline_inattention}, **shock_baseline} # update parameters used for all models


# init
models = {}
models_solved = {}
model_labels = {}
outputs = {}

# %%
# paths to plot
# paths = ['G', 'Y', 'C_hh', 'L_hh', 'A_hh', 'K', 'I', 'Z',
#          'N', 'w', 'tau', 'Pi', 'i', 'r',
#          'qB', 'p_eq', 'Div']
paths = ['G', 'Y', 'C_hh', 'I',
         'N', 'w', 'tau', 'Pi', 'r',
         'qB']
paths_short = ['Y', 'C_hh', 'K', 'I', 'N', 'w']
lvl_value = ['eg', 'em', 'ez', 'i', 'Pi', 'Pi_w']
abs_diff = ['r', 'ra', 'rl', 'i']
facs = {'r':100,'ra':100,'rl':100, 'i':100}

# %% [markdown]
# # Functions

# %%
def solve_model_list(models, compare_models, models_solved={}, use_baseline=None, do_non_linear=False):
    """ solve models and store in list

        :param models: dictionary of models with model parameter settings
        :param compare_models: list of model names from models dictionary to compare
        :param models_solved dictionary with solved models
        :param use_baseline: name of baseline model to use"""

    # init container for models
    for m in compare_models:
        # init model
        print('\r' + f' -------- Model: {m} ---------')

        updated_par_temp = {**updated_par_base, **models[m]}

        model = HANKStickyModelClass(name=m, par=updated_par_temp, savefolder=path_savefolder)

        if use_baseline != None:
            if use_baseline in models_solved:
                m_baseline = models_solved[use_baseline]
                model = HANKStickyAnalyticsClass.solution_routine(model, baseline_model=m_baseline, update_par=updated_par_temp, do_non_linear=do_non_linear)
            else:
                assert use_baseline == compare_models[
                    0], 'Baseline model has to be the first model that is solved if not already is models_solved dictionary'
                model = HANKStickyAnalyticsClass.solution_routine(model, baseline_model=None, do_non_linear=do_non_linear)
        else:
            model = HANKStickyAnalyticsClass.solution_routine(model, baseline_model=None, do_non_linear=do_non_linear)

        models_solved[m] = model

    return models_solved

# %%
# def solution_routine(model, baseline_model=None, update_par={}, do_non_linear=False, save_model=False):
#     """ solve model
#
#         :param model: initialied model.
#         :param baseline_model: use steady state from this baseline model and only compute jacs and IRFs.
#         :param update_par: specify parameters to update from baseline model.
#         :param do_non_linear: find non-linear transition path if TRUE.
#         :param save_model: save model with date timestamp if TRUE."""
#
#     if baseline_model == None:
#         print("\r"+'Find steady state  ',end="")
#         model.find_ss(do_print=False)
#     else:
#         print("\r"+f'Use steady state from {baseline_model.name}')
#         model = baseline_model.copy()
#         for p in update_par.keys():
#             model.par.__dict__[p] = update_par[p]
#
#     print("\r"+'Compute Jacobians  ',end="")
#     model.compute_jacs(do_print=False)
#     if do_non_linear:
#         print("\r"+'Find transition path',end="")
#         model.find_transition_path(do_print=False, do_print_unknowns=False)
#     print("\r"+'Find IRFs           ',end="")
#     model.find_IRFs(do_print=False)
#
#     if save_model:
#         m_name = model + f'_{datetime.datetime.now().strftime("%m_%d")}'
#         model.name = m_name
#         model.save()
#         print("\r"+f'saved {m_name}')
#
#     return model
#
# def solve_model_list(models, compare_models, models_solved={}, use_baseline=None, do_non_linear=False):
#     """ solve models and store in list
#
#         :param models: dictionary of models with model parameter settings
#         :param compare_models: list of model names from models dictionary to compare
#         :param models_solved dictionary with solved models
#         :param use_baseline: name of baseline model to use"""
#
#
#     # init container for models
#     for m in compare_models:
#         # init model
#         print('\r'+f' -------- Model: {m} ---------')
#
#         updated_par_temp = {**updated_par_base, **models[m]}
#
#         model = HANKStickyModelClass(name=m, par=updated_par_temp, savefolder=path_savefolder)
#
#         if use_baseline != None:
#             if use_baseline in models_solved:
#                 m_baseline = models_solved[use_baseline]
#                 model = solution_routine(model, baseline_model=m_baseline, update_par=updated_par_temp, do_non_linear=do_non_linear)
#             else:
#                 assert use_baseline == compare_models[0], 'Baseline model has to be the first model that is solved if not already is models_solved dictionary'
#                 model = solution_routine(model, baseline_model=None, do_non_linear=do_non_linear)
#         else:
#             model = solution_routine(model, baseline_model=None, do_non_linear=do_non_linear)
#
#         models_solved[m] = model
#
#     return models_solved
#
#
# def get_sticky_IRFs(model, inattention = 0.935):
#     """ get sticky information IRFs for list of models"""
#
#     m_sticky = f"{m}_sticky"
#
#     print('\r'+f' -------- Model: {m_sticky} ---------')
#
#     model_sticky = model.copy()
#
#     model_sticky.name = m_sticky
#
#     model_sticky.par.inattention = inattention
#
#     print("\r"+'Compute Jacobians',end="")
#     model_sticky.compute_jacs(do_print=False)
#     print("\r"+'Find IRFs',end="")
#     model_sticky.find_IRFs(do_print=False)
#
#     print("\r"+'                  ',end="")
#
#     return model_sticky

# %%
def get_no_IRF_output(model, result={}):
    """Savor MPCs and fiscal multipliers in dictionary"""

    m = model.name

    result_emtpy = {
        'MPC': {},
        'Fiscal Multiplier': {
            'impact': np.nan,
            'cumulative': np.nan
        },
        'JAC_diff':{
            'abs': np.nan,
            'perc': np.nan
        }
    }
    income_types_MPC = ['labor', 'liquid', 'illiquid']
    for i in income_types_MPC:
        result_emtpy['MPC'][i] = {
                'annual': np.nan,
                'quarterly': np.nan
                }

    result[m] = result_emtpy
    for i in income_types_MPC:
        for i_q, q_i in enumerate(['quarterly', 'annual']):
            result[m]['MPC'][i][q_i] = round(model.calc_MPC(annual=i_q, income=i), 3)
    fmp_impact, fmp_cum = model.calc_FMP()
    result[m]['Fiscal Multiplier']['impact'] = round(fmp_impact, 3)
    result[m]['Fiscal Multiplier']['cumulative'] = round(fmp_cum, 3)

# %% [markdown]
# Things to include:
# 1. Different spending types
# 2. Different shock trajectories
# 3. Different rigidity parameters
#    - Fiscal multiplier based on output being demand determined. Partial equilibrium logic from Hagedorn: "... ensures that the increase in government spending stimulates aggregate demand in the first place. The typical underlying assumption is that prices are rigid so that firms adjust quantities and not only prices in response to increased government demand. Firms increase production to satisfy this demand by raising employment, capital and wages, which leads to higher household income."
#    - Analysis about the multiplier " This requires a model that, first, features the right amount of nominal rigidities, so that the aggregate demand channel is as in the data"
#
# 4. Different MP reactions
# 5. Different inattention levels
# 6. MPC's
#     - "Important to also look at how MPCs change, because: " significant deviation from the permanent income hypothesis, such that households have a high marginal propensity to consume (MPC) out of the transitory increase in income induced by the stimulus, generating a nontrivial indirect effect.  Higher private consumption directly induced by government spending then leads to further increase in labor demand, income, consumption and so on."
#      - Analysis about fiscal multiplier  "requires incorporating observed marginal propensities to consume that imply a substantial deviation from the permanent income hypothesis"
# 7. FP shock persistence (big focus in "The intertemporal keynesian cross" paper.

# %% [markdown]
# # Spending types
# Compare responses of
#
# 1. a purely tax financed shock
# 2. a purely deficit financed shock
# 3. a shock that is financed by increased taxes and deficit

# %%
models['tax_financing'] = {
    'phi_G': 1.0,
    'inattention': 0.0
}

models['mixed_financing'] = {
    'phi_G': 0.5,
    'inattention': 0.0
}

models['deficit_financing'] = {
    'phi_G': 0.0,
    'inattention': 0.0
}

# %%
compare_models = ['tax_financing', 'deficit_financing', 'mixed_financing']
models_solved = solve_model_list(models, compare_models, models_solved, do_non_linear=False, use_baseline='tax_financing')
for m in compare_models:
    m_sticky = f"{m}_sticky"
    models_solved[m_sticky] = HANKStickyAnalyticsClass.get_sticky_IRFs(models_solved[m], inattention=baseline_inattention)
# Out:
#  -------- Model: tax_financing ---------
#  -------- Model: deficit_financing ---------
# Use steady state from tax_financing
#  -------- Model: mixed_financing ---------
# Use steady state from tax_financing
#  -------- Model: tax_financing_sticky ---------
#  -------- Model: deficit_financing_sticky ---------
#  -------- Model: mixed_financing_sticky ---------

# %%
for m in compare_models:
    get_no_IRF_output(models_solved[m], result=outputs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3760/286943526.py in <module>
#       1 for m in compare_models:
# ----> 2     get_no_IRF_output(models_solved[m], result=outputs)
#
# ~\AppData\Local\Temp/ipykernel_3760/764663597.py in get_no_IRF_output(model, result)
#      25     for i in income_types_MPC:
#      26         for i_q, q_i in enumerate(['quarterly', 'annual']):
# ---> 27             result[m]['MPC'][i][q_i] = round(model.calc_MPC(annual=i_q, income=i), 3)
#      28     fmp_impact, fmp_cum = model.calc_FMP()
#      29     result[m]['Fiscal Multiplier']['impact'] = round(fmp_impact, 3)
#
# ~\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\HANKStickyAnalyticsClass.py in calc_MPC(self, annual, income)
#      19         if income == 'labor':
#      20             # MPC from labor income
# ---> 21             assert jac_hh['C_hh', 'Z'].any(), 'Household Jacobian not calculated yet'
#      22
#      23             if annual:
#
# KeyError: ('C_hh', 'Z')

# %% [markdown]
# #### Plot

# %%
compare_models = ['tax_financing_sticky', 'deficit_financing_sticky', 'mixed_financing_sticky']
labels = [f'$\phi_G = 0, \\theta = {baseline_inattention}$', f'$\phi_G = 1, \\theta = {baseline_inattention}$', f'$\phi_G = 0.5, \\theta = {baseline_inattention}$']
models_list = [models_solved[m] for m in compare_models]
models_solved['tax_financing'].compare_IRFs(models_list, labels, paths, lvl_value=lvl_value, do_shocks=True, do_targets=False, ncols=3, do_linear=True, do_non_linear=False)

# %% [markdown]
# #### Other output

# %%
compare_models = ['tax_financing_sticky', 'deficit_financing_sticky', 'mixed_financing_sticky']
for m in compare_models:
    get_no_IRF_output(models_solved[m], result=outputs, models_solved=models_solved)
pd.DataFrame.from_dict(outputs).T

# %%
# reset dictionaries to save memory
models = {}
models_solved = {}
model_labels = {}

# %% [markdown]
# ## Tax rate responsivness
#
# For a deficit financed shock, the speed of adjustment of the tax rate can differ.
# If the tax rate does not adjust, there is no convergence to the old steady state with the previous debt ratio.

# %%
models['deficit_financing_phi_tau_005'] = {
    'phi_G': 0.0,
    'phi_tau': 0.05,
    'inattention': 0.0
}
models['deficit_financing_phi_tau_01'] = {
    'phi_G': 0.0,
    'phi_tau': 0.1,
    'inattention': 0.0
}
models['deficit_financing_phi_tau_0025'] = {
    'phi_G': 0.0,
    'phi_tau': 0.025,
    'inattention': 0.0
}

# %%
compare_models_no_sticky = ['deficit_financing_phi_tau_01', 'deficit_financing_phi_tau_005', 'deficit_financing_phi_tau_0025']
models_solved = solve_model_list(models, compare_models_no_sticky, models_solved, do_non_linear=False, use_baseline='deficit_financing_phi_tau_01')
for m in compare_models_no_sticky:
    m_sticky = f"{m}_sticky"
    models_solved[m_sticky] = HANKStickyAnalyticsClass.get_sticky_IRFs(models_solved[m], inattention=baseline_inattention)
# Out:
#  -------- Model: deficit_financing_phi_tau_01 ---------
# Use steady state from deficit_financing_phi_tau_01
#  -------- Model: deficit_financing_phi_tau_005 ---------
# Use steady state from deficit_financing_phi_tau_01_copy
#  -------- Model: deficit_financing_phi_tau_001 ---------
# Use steady state from deficit_financing_phi_tau_01_copy
#  -------- Model: Modelclass: HANKStickyModelClass
# Name: deficit_financing_phi_tau_01_copy
#
# namespaces: ['par', 'ini', 'sim', 'ss', 'path']
# other_attrs: ['par', 'ini', 'ss', 'path', 'sim', 'grids_hh', 'pols_hh', 'inputs_hh', 'inputs_hh_z', 'outputs_hh', 'intertemps_hh', 'shocks', 'unknowns', 'targets', 'varlist', 'jac', 'H_U', 'H_Z', 'jac_hh', 'IRF']
# savefolder: C:\Users\Yannik\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\saved_models
# cpp_filename: None
#
# par:
#  Nfix = 1 [int]
#  Nz = 7 [int]
#  r_ss_target = 0.012272234429039353 [float]
#  K_Y_ratio = 8.92 [float]
#  L_Y_ratio = 0.92 [float]
#  hh_wealth_Y_ratio = 15.28 [float]
#  G_Y_ratio = 0.16 [float]
#  qB_Y_ratio = 1.68 [float]
#  A_Y_ratio = 14.36 [float]
#  A_target = 14.36 [float]
#  sigma = 1.0 [float]
#  beta_mean = 0.995131998121411 [float64]
#  beta_delta = 0.0 [float]
#  frisch = 0.5 [float]
#  nu = 0.6763034653036701 [float64]
#  inattention = 0.0 [float]
#  rho_e = 0.966 [float]
#  sigma_e = 0.5 [float]
#  chi = 0.009 [float]
#  Theta = 0.5894649607474207 [float]
#  alpha = 0.24153040201445486 [float]
#  delta_K = 0.01325 [float]
#  mu_p = 1.0609337283637648 [float]
#  e_p = 17.41127216162053 [float]
#  xi_p = 0.926 [float]
#  v_p = 20 [int]
#  phi_K = 3.0 [float]
#  xi_w = 0.899 [float]
#  e_w = 17.41127216162053 [float]
#  v_w = 20 [int]
#  rho_m = 0.89 [float]
#  phi_pi = 1.25 [float]
#  phi_tau = 0.1 [float]
#  phi_G = 0.0 [float]
#  delta_q = 0.9616586227075874 [float]
#  taylor = additive [str]
#  xi = 0.01604351467440368 [float]
#  l_min = 0.0 [float]
#  l_max = 30.0 [float]
#  Nl = 100 [int]
#  a_min = 0.0 [float]
#  a_max = 30.0 [float]
#  Na = 100 [int]
#  jump_eg = 0.0001 [float]
#  rho_eg = 0.7 [float]
#  std_eg = 0.0 [float]
#  jump_em = 0.0 [float]
#  rho_em = 0.6 [float]
#  std_em = 0.0 [float]
#  jump_ez = 0.0 [float]
#  rho_ez = 0.6 [float]
#  std_ez = 0.0 [float]
#  T = 250 [int]
#  simT = 100 [int]
#  max_iter_solve = 50000 [int]
#  max_iter_simulate = 50000 [int]
#  max_iter_broyden = 100 [int]
#  tol_ss = 1e-12 [float]
#  tol_solve = 1e-12 [float]
#  tol_simulate = 1e-12 [float]
#  tol_broyden = 1e-12 [float]
#  start_dbeg_opti = True
#  print_non_lin_warning = False
#  beta_grid = ndarray with shape = (1,) [dtype: float64]
#  l_grid = ndarray with shape = (100,) [dtype: float64]
#  a_grid = ndarray with shape = (100,) [dtype: float64]
#  z_grid = ndarray with shape = (7,) [dtype: float64]
#  memory, gb: 0.0
#
# ini:
#  Dz = ndarray with shape = (1, 7) [dtype: float64]
#  Dbeg = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  A = 14.36 [float]
#  B = 0.08503086769203928 [float]
#  clearing_A = 2.3447910280083306e-13 [float64]
#  clearing_L = -3.510385315763642e-10 [float64]
#  clearing_C = nan [float]
#  clearing_Y = -1.5543122344752192e-15 [float64]
#  Div_int = 0.05743405712790406 [float]
#  Div_k = 0.10946833110703102 [float]
#  Div = 0.1669023882349351 [float]
#  eg = 0.0 [float]
#  ez = 0.0 [float]
#  em = 0.0 [float]
#  fisher_res = nan [float]
#  G = 0.16 [float]
#  i = 0.012272234429039353 [float]
#  I = 0.11818999999999999 [float]
#  invest_res = nan [float]
#  Ip = 0.11818999999999999 [float]
#  K = 8.92 [float]
#  L = 0.92 [float]
#  N = 1.0 [float]
#  p_eq = 13.599999999999993 [float]
#  p_int = 4.679999999999991 [float]
#  p_k = 8.92 [float]
#  p_share = nan [float]
#  Pi_increase = 0.0 [float]
#  Pi_w_increase = 0.0 [float]
#  Pi_w = 0.0 [float]
#  Pi = 0.0 [float]
#  psi = 0.0 [float]
#  q = 19.757530948461486 [float]
#  Q = 1.0 [float]
#  qB = 1.68 [float]
#  r = 0.012272234429039353 [float]
#  ra = 0.012272234429039353 [float]
#  rk = 0.02552223442903935 [float]
#  rl = -0.003771280245364328 [float]
#  s_w = 0.9425659428720959 [float]
#  s = 0.9425659428720959 [float]
#  tau = 0.25264432895720973 [float]
#  wN = 0.7149076117650649 [float]
#  valuation_res = nan [float]
#  w_res = nan [float]
#  w = 0.7149076117650649 [float]
#  Y = 1.0 [float]
#  Z = 0.5342902579242786 [float]
#  C_hh = 0.707049966505182 [float64]
#  L_hh = 0.9199999996489615 [float64]
#  A_hh = 14.360000000000234 [float64]
#  UCE_hh = 1.3429276433702917 [float64]
#  memory, gb: 0.0
#
# sim:
#  l = ndarray with shape = (100, 1, 7, 100, 100) [dtype: float64]
#  L_hh_from_D = ndarray with shape = (100,) [dtype: float64]
#  a = ndarray with shape = (100, 1, 7, 100, 100) [dtype: float64]
#  A_hh_from_D = ndarray with shape = (100,) [dtype: float64]
#  z_trans = ndarray with shape = (100, 1, 7, 7) [dtype: float64]
#  Dz = ndarray with shape = (100, 1, 7) [dtype: float64]
#  D = ndarray with shape = (100, 1, 7, 100, 100) [dtype: float64]
#  Dbeg = ndarray with shape = (100, 1, 7, 100, 100) [dtype: float64]
#  pol_indices = ndarray with shape = (100, 2, 1, 7, 100, 100) [dtype: int32]
#  pol_weights = ndarray with shape = (100, 2, 1, 7, 100, 100) [dtype: float64]
#  dA = ndarray with shape = (100,) [dtype: float64]
#  dB = ndarray with shape = (100,) [dtype: float64]
#  dclearing_A = ndarray with shape = (100,) [dtype: float64]
#  dclearing_L = ndarray with shape = (100,) [dtype: float64]
#  dclearing_C = ndarray with shape = (100,) [dtype: float64]
#  dclearing_Y = ndarray with shape = (100,) [dtype: float64]
#  dDiv_int = ndarray with shape = (100,) [dtype: float64]
#  dDiv_k = ndarray with shape = (100,) [dtype: float64]
#  dDiv = ndarray with shape = (100,) [dtype: float64]
#  deg = ndarray with shape = (100,) [dtype: float64]
#  dez = ndarray with shape = (100,) [dtype: float64]
#  dem = ndarray with shape = (100,) [dtype: float64]
#  dfisher_res = ndarray with shape = (100,) [dtype: float64]
#  dG = ndarray with shape = (100,) [dtype: float64]
#  di = ndarray with shape = (100,) [dtype: float64]
#  dI = ndarray with shape = (100,) [dtype: float64]
#  dinvest_res = ndarray with shape = (100,) [dtype: float64]
#  dIp = ndarray with shape = (100,) [dtype: float64]
#  dK = ndarray with shape = (100,) [dtype: float64]
#  dL = ndarray with shape = (100,) [dtype: float64]
#  dN = ndarray with shape = (100,) [dtype: float64]
#  dp_eq = ndarray with shape = (100,) [dtype: float64]
#  dp_int = ndarray with shape = (100,) [dtype: float64]
#  dp_k = ndarray with shape = (100,) [dtype: float64]
#  dp_share = ndarray with shape = (100,) [dtype: float64]
#  dPi_increase = ndarray with shape = (100,) [dtype: float64]
#  dPi_w_increase = ndarray with shape = (100,) [dtype: float64]
#  dPi_w = ndarray with shape = (100,) [dtype: float64]
#  dPi = ndarray with shape = (100,) [dtype: float64]
#  dpsi = ndarray with shape = (100,) [dtype: float64]
#  dq = ndarray with shape = (100,) [dtype: float64]
#  dQ = ndarray with shape = (100,) [dtype: float64]
#  dqB = ndarray with shape = (100,) [dtype: float64]
#  dr = ndarray with shape = (100,) [dtype: float64]
#  dra = ndarray with shape = (100,) [dtype: float64]
#  drk = ndarray with shape = (100,) [dtype: float64]
#  drl = ndarray with shape = (100,) [dtype: float64]
#  ds_w = ndarray with shape = (100,) [dtype: float64]
#  ds = ndarray with shape = (100,) [dtype: float64]
#  dtau = ndarray with shape = (100,) [dtype: float64]
#  dwN = ndarray with shape = (100,) [dtype: float64]
#  dvaluation_res = ndarray with shape = (100,) [dtype: float64]
#  dw_res = ndarray with shape = (100,) [dtype: float64]
#  dw = ndarray with shape = (100,) [dtype: float64]
#  dY = ndarray with shape = (100,) [dtype: float64]
#  dZ = ndarray with shape = (100,) [dtype: float64]
#  dC_hh = ndarray with shape = (100,) [dtype: float64]
#  dL_hh = ndarray with shape = (100,) [dtype: float64]
#  dA_hh = ndarray with shape = (100,) [dtype: float64]
#  dUCE_hh = ndarray with shape = (100,) [dtype: float64]
#  memory, gb: 0.4
#
# ss:
#  c = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  l = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  a = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  uce = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  vbeg_l_a = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  z_trans = ndarray with shape = (1, 7, 7) [dtype: float64]
#  Dz = ndarray with shape = (1, 7) [dtype: float64]
#  D = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  Dbeg = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  pol_indices = ndarray with shape = (2, 1, 7, 100, 100) [dtype: int32]
#  pol_weights = ndarray with shape = (2, 1, 7, 100, 100) [dtype: float64]
#  A = 14.36 [float]
#  B = 0.08503086769203928 [float]
#  clearing_A = 2.3447910280083306e-13 [float64]
#  clearing_L = -3.510385315763642e-10 [float64]
#  clearing_C = nan [float]
#  clearing_Y = -1.5543122344752192e-15 [float64]
#  Div_int = 0.05743405712790406 [float]
#  Div_k = 0.10946833110703102 [float]
#  Div = 0.1669023882349351 [float]
#  eg = 0.0 [float]
#  ez = 0.0 [float]
#  em = 0.0 [float]
#  fisher_res = nan [float]
#  G = 0.16 [float]
#  i = 0.012272234429039353 [float]
#  I = 0.11818999999999999 [float]
#  invest_res = nan [float]
#  Ip = 0.11818999999999999 [float]
#  K = 8.92 [float]
#  L = 0.92 [float]
#  N = 1.0 [float]
#  p_eq = 13.599999999999993 [float]
#  p_int = 4.679999999999991 [float]
#  p_k = 8.92 [float]
#  p_share = nan [float]
#  Pi_increase = 0.0 [float]
#  Pi_w_increase = 0.0 [float]
#  Pi_w = 0.0 [float]
#  Pi = 0.0 [float]
#  psi = 0.0 [float]
#  q = 19.757530948461486 [float]
#  Q = 1.0 [float]
#  qB = 1.68 [float]
#  r = 0.012272234429039353 [float]
#  ra = 0.012272234429039353 [float]
#  rk = 0.02552223442903935 [float]
#  rl = -0.003771280245364328 [float]
#  s_w = 0.9425659428720959 [float]
#  s = 0.9425659428720959 [float]
#  tau = 0.25264432895720973 [float]
#  wN = 0.7149076117650649 [float]
#  valuation_res = nan [float]
#  w_res = nan [float]
#  w = 0.7149076117650649 [float]
#  Y = 1.0 [float]
#  Z = 0.5342902579242786 [float]
#  C_hh = 0.707049966505182 [float64]
#  L_hh = 0.9199999996489615 [float64]
#  A_hh = 14.360000000000234 [float64]
#  UCE_hh = 1.3429276433702917 [float64]
#  memory, gb: 0.0
#
# path:
#  c = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  l = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  a = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  uce = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  vbeg_l_a = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  z_trans = ndarray with shape = (250, 1, 7, 7) [dtype: float64]
#  Dz = ndarray with shape = (250, 1, 7) [dtype: float64]
#  D = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  Dbeg = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  pol_indices = ndarray with shape = (250, 2, 1, 7, 100, 100) [dtype: int32]
#  pol_weights = ndarray with shape = (250, 2, 1, 7, 100, 100) [dtype: float64]
#  A = ndarray with shape = (1250, 250) [dtype: float64]
#  B = ndarray with shape = (1250, 250) [dtype: float64]
#  clearing_A = ndarray with shape = (1250, 250) [dtype: float64]
#  clearing_L = ndarray with shape = (1250, 250) [dtype: float64]
#  clearing_C = ndarray with shape = (1250, 250) [dtype: float64]
#  clearing_Y = ndarray with shape = (1250, 250) [dtype: float64]
#  Div_int = ndarray with shape = (1250, 250) [dtype: float64]
#  Div_k = ndarray with shape = (1250, 250) [dtype: float64]
#  Div = ndarray with shape = (1250, 250) [dtype: float64]
#  eg = ndarray with shape = (1250, 250) [dtype: float64]
#  ez = ndarray with shape = (1250, 250) [dtype: float64]
#  em = ndarray with shape = (1250, 250) [dtype: float64]
#  fisher_res = ndarray with shape = (1250, 250) [dtype: float64]
#  G = ndarray with shape = (1250, 250) [dtype: float64]
#  i = ndarray with shape = (1250, 250) [dtype: float64]
#  I = ndarray with shape = (1250, 250) [dtype: float64]
#  invest_res = ndarray with shape = (1250, 250) [dtype: float64]
#  Ip = ndarray with shape = (1250, 250) [dtype: float64]
#  K = ndarray with shape = (1250, 250) [dtype: float64]
#  L = ndarray with shape = (1250, 250) [dtype: float64]
#  N = ndarray with shape = (1250, 250) [dtype: float64]
#  p_eq = ndarray with shape = (1250, 250) [dtype: float64]
#  p_int = ndarray with shape = (1250, 250) [dtype: float64]
#  p_k = ndarray with shape = (1250, 250) [dtype: float64]
#  p_share = ndarray with shape = (1250, 250) [dtype: float64]
#  Pi_increase = ndarray with shape = (1250, 250) [dtype: float64]
#  Pi_w_increase = ndarray with shape = (1250, 250) [dtype: float64]
#  Pi_w = ndarray with shape = (1250, 250) [dtype: float64]
#  Pi = ndarray with shape = (1250, 250) [dtype: float64]
#  psi = ndarray with shape = (1250, 250) [dtype: float64]
#  q = ndarray with shape = (1250, 250) [dtype: float64]
#  Q = ndarray with shape = (1250, 250) [dtype: float64]
#  qB = ndarray with shape = (1250, 250) [dtype: float64]
#  r = ndarray with shape = (1250, 250) [dtype: float64]
#  ra = ndarray with shape = (1250, 250) [dtype: float64]
#  rk = ndarray with shape = (1250, 250) [dtype: float64]
#  rl = ndarray with shape = (1250, 250) [dtype: float64]
#  s_w = ndarray with shape = (1250, 250) [dtype: float64]
#  s = ndarray with shape = (1250, 250) [dtype: float64]
#  tau = ndarray with shape = (1250, 250) [dtype: float64]
#  wN = ndarray with shape = (1250, 250) [dtype: float64]
#  valuation_res = ndarray with shape = (1250, 250) [dtype: float64]
#  w_res = ndarray with shape = (1250, 250) [dtype: float64]
#  w = ndarray with shape = (1250, 250) [dtype: float64]
#  Y = ndarray with shape = (1250, 250) [dtype: float64]
#  Z = ndarray with shape = (1250, 250) [dtype: float64]
#  C_hh = ndarray with shape = (1250, 250) [dtype: float64]
#  L_hh = ndarray with shape = (1250, 250) [dtype: float64]
#  A_hh = ndarray with shape = (1250, 250) [dtype: float64]
#  UCE_hh = ndarray with shape = (1250, 250) [dtype: float64]
#  memory, gb: 1.5
# _sticky ---------
#  -------- Model: Modelclass: HANKStickyModelClass
# Name: deficit_financing_phi_tau_01_copy_copy
#
# namespaces: ['par', 'ini', 'sim', 'ss', 'path']
# other_attrs: ['par', 'ini', 'ss', 'path', 'sim', 'grids_hh', 'pols_hh', 'inputs_hh', 'inputs_hh_z', 'outputs_hh', 'intertemps_hh', 'shocks', 'unknowns', 'targets', 'varlist', 'jac', 'H_U', 'H_Z', 'jac_hh', 'IRF']
# savefolder: C:\Users\Yannik\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\saved_models
# cpp_filename: None
#
# par:
#  Nfix = 1 [int]
#  Nz = 7 [int]
#  r_ss_target = 0.012272234429039353 [float]
#  K_Y_ratio = 8.92 [float]
#  L_Y_ratio = 0.92 [float]
#  hh_wealth_Y_ratio = 15.28 [float]
#  G_Y_ratio = 0.16 [float]
#  qB_Y_ratio = 1.68 [float]
#  A_Y_ratio = 14.36 [float]
#  A_target = 14.36 [float]
#  sigma = 1.0 [float]
#  beta_mean = 0.995131998121411 [float64]
#  beta_delta = 0.0 [float]
#  frisch = 0.5 [float]
#  nu = 0.6763034653036701 [float64]
#  inattention = 0.0 [float]
#  rho_e = 0.966 [float]
#  sigma_e = 0.5 [float]
#  chi = 0.009 [float]
#  Theta = 0.5894649607474207 [float]
#  alpha = 0.24153040201445486 [float]
#  delta_K = 0.01325 [float]
#  mu_p = 1.0609337283637648 [float]
#  e_p = 17.41127216162053 [float]
#  xi_p = 0.926 [float]
#  v_p = 20 [int]
#  phi_K = 3.0 [float]
#  xi_w = 0.899 [float]
#  e_w = 17.41127216162053 [float]
#  v_w = 20 [int]
#  rho_m = 0.89 [float]
#  phi_pi = 1.25 [float]
#  phi_tau = 0.05 [float]
#  phi_G = 0.0 [float]
#  delta_q = 0.9616586227075874 [float]
#  taylor = additive [str]
#  xi = 0.01604351467440368 [float]
#  l_min = 0.0 [float]
#  l_max = 30.0 [float]
#  Nl = 100 [int]
#  a_min = 0.0 [float]
#  a_max = 30.0 [float]
#  Na = 100 [int]
#  jump_eg = 0.0001 [float]
#  rho_eg = 0.7 [float]
#  std_eg = 0.0 [float]
#  jump_em = 0.0 [float]
#  rho_em = 0.6 [float]
#  std_em = 0.0 [float]
#  jump_ez = 0.0 [float]
#  rho_ez = 0.6 [float]
#  std_ez = 0.0 [float]
#  T = 250 [int]
#  simT = 100 [int]
#  max_iter_solve = 50000 [int]
#  max_iter_simulate = 50000 [int]
#  max_iter_broyden = 100 [int]
#  tol_ss = 1e-12 [float]
#  tol_solve = 1e-12 [float]
#  tol_simulate = 1e-12 [float]
#  tol_broyden = 1e-12 [float]
#  start_dbeg_opti = True
#  print_non_lin_warning = False
#  beta_grid = ndarray with shape = (1,) [dtype: float64]
#  l_grid = ndarray with shape = (100,) [dtype: float64]
#  a_grid = ndarray with shape = (100,) [dtype: float64]
#  z_grid = ndarray with shape = (7,) [dtype: float64]
#  memory, gb: 0.0
#
# ini:
#  Dz = ndarray with shape = (1, 7) [dtype: float64]
#  Dbeg = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  A = 14.36 [float]
#  B = 0.08503086769203928 [float]
#  clearing_A = 2.3447910280083306e-13 [float64]
#  clearing_L = -3.510385315763642e-10 [float64]
#  clearing_C = nan [float]
#  clearing_Y = -1.5543122344752192e-15 [float64]
#  Div_int = 0.05743405712790406 [float]
#  Div_k = 0.10946833110703102 [float]
#  Div = 0.1669023882349351 [float]
#  eg = 0.0 [float]
#  ez = 0.0 [float]
#  em = 0.0 [float]
#  fisher_res = nan [float]
#  G = 0.16 [float]
#  i = 0.012272234429039353 [float]
#  I = 0.11818999999999999 [float]
#  invest_res = nan [float]
#  Ip = 0.11818999999999999 [float]
#  K = 8.92 [float]
#  L = 0.92 [float]
#  N = 1.0 [float]
#  p_eq = 13.599999999999993 [float]
#  p_int = 4.679999999999991 [float]
#  p_k = 8.92 [float]
#  p_share = nan [float]
#  Pi_increase = 0.0 [float]
#  Pi_w_increase = 0.0 [float]
#  Pi_w = 0.0 [float]
#  Pi = 0.0 [float]
#  psi = 0.0 [float]
#  q = 19.757530948461486 [float]
#  Q = 1.0 [float]
#  qB = 1.68 [float]
#  r = 0.012272234429039353 [float]
#  ra = 0.012272234429039353 [float]
#  rk = 0.02552223442903935 [float]
#  rl = -0.003771280245364328 [float]
#  s_w = 0.9425659428720959 [float]
#  s = 0.9425659428720959 [float]
#  tau = 0.25264432895720973 [float]
#  wN = 0.7149076117650649 [float]
#  valuation_res = nan [float]
#  w_res = nan [float]
#  w = 0.7149076117650649 [float]
#  Y = 1.0 [float]
#  Z = 0.5342902579242786 [float]
#  C_hh = 0.707049966505182 [float64]
#  L_hh = 0.9199999996489615 [float64]
#  A_hh = 14.360000000000234 [float64]
#  UCE_hh = 1.3429276433702917 [float64]
#  memory, gb: 0.0
#
# sim:
#  l = ndarray with shape = (100, 1, 7, 100, 100) [dtype: float64]
#  L_hh_from_D = ndarray with shape = (100,) [dtype: float64]
#  a = ndarray with shape = (100, 1, 7, 100, 100) [dtype: float64]
#  A_hh_from_D = ndarray with shape = (100,) [dtype: float64]
#  z_trans = ndarray with shape = (100, 1, 7, 7) [dtype: float64]
#  Dz = ndarray with shape = (100, 1, 7) [dtype: float64]
#  D = ndarray with shape = (100, 1, 7, 100, 100) [dtype: float64]
#  Dbeg = ndarray with shape = (100, 1, 7, 100, 100) [dtype: float64]
#  pol_indices = ndarray with shape = (100, 2, 1, 7, 100, 100) [dtype: int32]
#  pol_weights = ndarray with shape = (100, 2, 1, 7, 100, 100) [dtype: float64]
#  dA = ndarray with shape = (100,) [dtype: float64]
#  dB = ndarray with shape = (100,) [dtype: float64]
#  dclearing_A = ndarray with shape = (100,) [dtype: float64]
#  dclearing_L = ndarray with shape = (100,) [dtype: float64]
#  dclearing_C = ndarray with shape = (100,) [dtype: float64]
#  dclearing_Y = ndarray with shape = (100,) [dtype: float64]
#  dDiv_int = ndarray with shape = (100,) [dtype: float64]
#  dDiv_k = ndarray with shape = (100,) [dtype: float64]
#  dDiv = ndarray with shape = (100,) [dtype: float64]
#  deg = ndarray with shape = (100,) [dtype: float64]
#  dez = ndarray with shape = (100,) [dtype: float64]
#  dem = ndarray with shape = (100,) [dtype: float64]
#  dfisher_res = ndarray with shape = (100,) [dtype: float64]
#  dG = ndarray with shape = (100,) [dtype: float64]
#  di = ndarray with shape = (100,) [dtype: float64]
#  dI = ndarray with shape = (100,) [dtype: float64]
#  dinvest_res = ndarray with shape = (100,) [dtype: float64]
#  dIp = ndarray with shape = (100,) [dtype: float64]
#  dK = ndarray with shape = (100,) [dtype: float64]
#  dL = ndarray with shape = (100,) [dtype: float64]
#  dN = ndarray with shape = (100,) [dtype: float64]
#  dp_eq = ndarray with shape = (100,) [dtype: float64]
#  dp_int = ndarray with shape = (100,) [dtype: float64]
#  dp_k = ndarray with shape = (100,) [dtype: float64]
#  dp_share = ndarray with shape = (100,) [dtype: float64]
#  dPi_increase = ndarray with shape = (100,) [dtype: float64]
#  dPi_w_increase = ndarray with shape = (100,) [dtype: float64]
#  dPi_w = ndarray with shape = (100,) [dtype: float64]
#  dPi = ndarray with shape = (100,) [dtype: float64]
#  dpsi = ndarray with shape = (100,) [dtype: float64]
#  dq = ndarray with shape = (100,) [dtype: float64]
#  dQ = ndarray with shape = (100,) [dtype: float64]
#  dqB = ndarray with shape = (100,) [dtype: float64]
#  dr = ndarray with shape = (100,) [dtype: float64]
#  dra = ndarray with shape = (100,) [dtype: float64]
#  drk = ndarray with shape = (100,) [dtype: float64]
#  drl = ndarray with shape = (100,) [dtype: float64]
#  ds_w = ndarray with shape = (100,) [dtype: float64]
#  ds = ndarray with shape = (100,) [dtype: float64]
#  dtau = ndarray with shape = (100,) [dtype: float64]
#  dwN = ndarray with shape = (100,) [dtype: float64]
#  dvaluation_res = ndarray with shape = (100,) [dtype: float64]
#  dw_res = ndarray with shape = (100,) [dtype: float64]
#  dw = ndarray with shape = (100,) [dtype: float64]
#  dY = ndarray with shape = (100,) [dtype: float64]
#  dZ = ndarray with shape = (100,) [dtype: float64]
#  dC_hh = ndarray with shape = (100,) [dtype: float64]
#  dL_hh = ndarray with shape = (100,) [dtype: float64]
#  dA_hh = ndarray with shape = (100,) [dtype: float64]
#  dUCE_hh = ndarray with shape = (100,) [dtype: float64]
#  memory, gb: 0.4
#
# ss:
#  c = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  l = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  a = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  uce = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  vbeg_l_a = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  z_trans = ndarray with shape = (1, 7, 7) [dtype: float64]
#  Dz = ndarray with shape = (1, 7) [dtype: float64]
#  D = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  Dbeg = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  pol_indices = ndarray with shape = (2, 1, 7, 100, 100) [dtype: int32]
#  pol_weights = ndarray with shape = (2, 1, 7, 100, 100) [dtype: float64]
#  A = 14.36 [float]
#  B = 0.08503086769203928 [float]
#  clearing_A = 2.3447910280083306e-13 [float64]
#  clearing_L = -3.510385315763642e-10 [float64]
#  clearing_C = nan [float]
#  clearing_Y = -1.5543122344752192e-15 [float64]
#  Div_int = 0.05743405712790406 [float]
#  Div_k = 0.10946833110703102 [float]
#  Div = 0.1669023882349351 [float]
#  eg = 0.0 [float]
#  ez = 0.0 [float]
#  em = 0.0 [float]
#  fisher_res = nan [float]
#  G = 0.16 [float]
#  i = 0.012272234429039353 [float]
#  I = 0.11818999999999999 [float]
#  invest_res = nan [float]
#  Ip = 0.11818999999999999 [float]
#  K = 8.92 [float]
#  L = 0.92 [float]
#  N = 1.0 [float]
#  p_eq = 13.599999999999993 [float]
#  p_int = 4.679999999999991 [float]
#  p_k = 8.92 [float]
#  p_share = nan [float]
#  Pi_increase = 0.0 [float]
#  Pi_w_increase = 0.0 [float]
#  Pi_w = 0.0 [float]
#  Pi = 0.0 [float]
#  psi = 0.0 [float]
#  q = 19.757530948461486 [float]
#  Q = 1.0 [float]
#  qB = 1.68 [float]
#  r = 0.012272234429039353 [float]
#  ra = 0.012272234429039353 [float]
#  rk = 0.02552223442903935 [float]
#  rl = -0.003771280245364328 [float]
#  s_w = 0.9425659428720959 [float]
#  s = 0.9425659428720959 [float]
#  tau = 0.25264432895720973 [float]
#  wN = 0.7149076117650649 [float]
#  valuation_res = nan [float]
#  w_res = nan [float]
#  w = 0.7149076117650649 [float]
#  Y = 1.0 [float]
#  Z = 0.5342902579242786 [float]
#  C_hh = 0.707049966505182 [float64]
#  L_hh = 0.9199999996489615 [float64]
#  A_hh = 14.360000000000234 [float64]
#  UCE_hh = 1.3429276433702917 [float64]
#  memory, gb: 0.0
#
# path:
#  c = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  l = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  a = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  uce = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  vbeg_l_a = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  z_trans = ndarray with shape = (250, 1, 7, 7) [dtype: float64]
#  Dz = ndarray with shape = (250, 1, 7) [dtype: float64]
#  D = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  Dbeg = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  pol_indices = ndarray with shape = (250, 2, 1, 7, 100, 100) [dtype: int32]
#  pol_weights = ndarray with shape = (250, 2, 1, 7, 100, 100) [dtype: float64]
#  A = ndarray with shape = (1250, 250) [dtype: float64]
#  B = ndarray with shape = (1250, 250) [dtype: float64]
#  clearing_A = ndarray with shape = (1250, 250) [dtype: float64]
#  clearing_L = ndarray with shape = (1250, 250) [dtype: float64]
#  clearing_C = ndarray with shape = (1250, 250) [dtype: float64]
#  clearing_Y = ndarray with shape = (1250, 250) [dtype: float64]
#  Div_int = ndarray with shape = (1250, 250) [dtype: float64]
#  Div_k = ndarray with shape = (1250, 250) [dtype: float64]
#  Div = ndarray with shape = (1250, 250) [dtype: float64]
#  eg = ndarray with shape = (1250, 250) [dtype: float64]
#  ez = ndarray with shape = (1250, 250) [dtype: float64]
#  em = ndarray with shape = (1250, 250) [dtype: float64]
#  fisher_res = ndarray with shape = (1250, 250) [dtype: float64]
#  G = ndarray with shape = (1250, 250) [dtype: float64]
#  i = ndarray with shape = (1250, 250) [dtype: float64]
#  I = ndarray with shape = (1250, 250) [dtype: float64]
#  invest_res = ndarray with shape = (1250, 250) [dtype: float64]
#  Ip = ndarray with shape = (1250, 250) [dtype: float64]
#  K = ndarray with shape = (1250, 250) [dtype: float64]
#  L = ndarray with shape = (1250, 250) [dtype: float64]
#  N = ndarray with shape = (1250, 250) [dtype: float64]
#  p_eq = ndarray with shape = (1250, 250) [dtype: float64]
#  p_int = ndarray with shape = (1250, 250) [dtype: float64]
#  p_k = ndarray with shape = (1250, 250) [dtype: float64]
#  p_share = ndarray with shape = (1250, 250) [dtype: float64]
#  Pi_increase = ndarray with shape = (1250, 250) [dtype: float64]
#  Pi_w_increase = ndarray with shape = (1250, 250) [dtype: float64]
#  Pi_w = ndarray with shape = (1250, 250) [dtype: float64]
#  Pi = ndarray with shape = (1250, 250) [dtype: float64]
#  psi = ndarray with shape = (1250, 250) [dtype: float64]
#  q = ndarray with shape = (1250, 250) [dtype: float64]
#  Q = ndarray with shape = (1250, 250) [dtype: float64]
#  qB = ndarray with shape = (1250, 250) [dtype: float64]
#  r = ndarray with shape = (1250, 250) [dtype: float64]
#  ra = ndarray with shape = (1250, 250) [dtype: float64]
#  rk = ndarray with shape = (1250, 250) [dtype: float64]
#  rl = ndarray with shape = (1250, 250) [dtype: float64]
#  s_w = ndarray with shape = (1250, 250) [dtype: float64]
#  s = ndarray with shape = (1250, 250) [dtype: float64]
#  tau = ndarray with shape = (1250, 250) [dtype: float64]
#  wN = ndarray with shape = (1250, 250) [dtype: float64]
#  valuation_res = ndarray with shape = (1250, 250) [dtype: float64]
#  w_res = ndarray with shape = (1250, 250) [dtype: float64]
#  w = ndarray with shape = (1250, 250) [dtype: float64]
#  Y = ndarray with shape = (1250, 250) [dtype: float64]
#  Z = ndarray with shape = (1250, 250) [dtype: float64]
#  C_hh = ndarray with shape = (1250, 250) [dtype: float64]
#  L_hh = ndarray with shape = (1250, 250) [dtype: float64]
#  A_hh = ndarray with shape = (1250, 250) [dtype: float64]
#  UCE_hh = ndarray with shape = (1250, 250) [dtype: float64]
#  memory, gb: 1.5
# _sticky ---------
#  -------- Model: Modelclass: HANKStickyModelClass
# Name: deficit_financing_phi_tau_01_copy_copy
#
# namespaces: ['par', 'ini', 'sim', 'ss', 'path']
# other_attrs: ['par', 'ini', 'ss', 'path', 'sim', 'grids_hh', 'pols_hh', 'inputs_hh', 'inputs_hh_z', 'outputs_hh', 'intertemps_hh', 'shocks', 'unknowns', 'targets', 'varlist', 'jac', 'H_U', 'H_Z', 'jac_hh', 'IRF']
# savefolder: C:\Users\Yannik\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\saved_models
# cpp_filename: None
#
# par:
#  Nfix = 1 [int]
#  Nz = 7 [int]
#  r_ss_target = 0.012272234429039353 [float]
#  K_Y_ratio = 8.92 [float]
#  L_Y_ratio = 0.92 [float]
#  hh_wealth_Y_ratio = 15.28 [float]
#  G_Y_ratio = 0.16 [float]
#  qB_Y_ratio = 1.68 [float]
#  A_Y_ratio = 14.36 [float]
#  A_target = 14.36 [float]
#  sigma = 1.0 [float]
#  beta_mean = 0.995131998121411 [float64]
#  beta_delta = 0.0 [float]
#  frisch = 0.5 [float]
#  nu = 0.6763034653036701 [float64]
#  inattention = 0.0 [float]
#  rho_e = 0.966 [float]
#  sigma_e = 0.5 [float]
#  chi = 0.009 [float]
#  Theta = 0.5894649607474207 [float]
#  alpha = 0.24153040201445486 [float]
#  delta_K = 0.01325 [float]
#  mu_p = 1.0609337283637648 [float]
#  e_p = 17.41127216162053 [float]
#  xi_p = 0.926 [float]
#  v_p = 20 [int]
#  phi_K = 3.0 [float]
#  xi_w = 0.899 [float]
#  e_w = 17.41127216162053 [float]
#  v_w = 20 [int]
#  rho_m = 0.89 [float]
#  phi_pi = 1.25 [float]
#  phi_tau = 0.01 [float]
#  phi_G = 0.0 [float]
#  delta_q = 0.9616586227075874 [float]
#  taylor = additive [str]
#  xi = 0.01604351467440368 [float]
#  l_min = 0.0 [float]
#  l_max = 30.0 [float]
#  Nl = 100 [int]
#  a_min = 0.0 [float]
#  a_max = 30.0 [float]
#  Na = 100 [int]
#  jump_eg = 0.0001 [float]
#  rho_eg = 0.7 [float]
#  std_eg = 0.0 [float]
#  jump_em = 0.0 [float]
#  rho_em = 0.6 [float]
#  std_em = 0.0 [float]
#  jump_ez = 0.0 [float]
#  rho_ez = 0.6 [float]
#  std_ez = 0.0 [float]
#  T = 250 [int]
#  simT = 100 [int]
#  max_iter_solve = 50000 [int]
#  max_iter_simulate = 50000 [int]
#  max_iter_broyden = 100 [int]
#  tol_ss = 1e-12 [float]
#  tol_solve = 1e-12 [float]
#  tol_simulate = 1e-12 [float]
#  tol_broyden = 1e-12 [float]
#  start_dbeg_opti = True
#  print_non_lin_warning = False
#  beta_grid = ndarray with shape = (1,) [dtype: float64]
#  l_grid = ndarray with shape = (100,) [dtype: float64]
#  a_grid = ndarray with shape = (100,) [dtype: float64]
#  z_grid = ndarray with shape = (7,) [dtype: float64]
#  memory, gb: 0.0
#
# ini:
#  Dz = ndarray with shape = (1, 7) [dtype: float64]
#  Dbeg = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  A = 14.36 [float]
#  B = 0.08503086769203928 [float]
#  clearing_A = 2.3447910280083306e-13 [float64]
#  clearing_L = -3.510385315763642e-10 [float64]
#  clearing_C = nan [float]
#  clearing_Y = -1.5543122344752192e-15 [float64]
#  Div_int = 0.05743405712790406 [float]
#  Div_k = 0.10946833110703102 [float]
#  Div = 0.1669023882349351 [float]
#  eg = 0.0 [float]
#  ez = 0.0 [float]
#  em = 0.0 [float]
#  fisher_res = nan [float]
#  G = 0.16 [float]
#  i = 0.012272234429039353 [float]
#  I = 0.11818999999999999 [float]
#  invest_res = nan [float]
#  Ip = 0.11818999999999999 [float]
#  K = 8.92 [float]
#  L = 0.92 [float]
#  N = 1.0 [float]
#  p_eq = 13.599999999999993 [float]
#  p_int = 4.679999999999991 [float]
#  p_k = 8.92 [float]
#  p_share = nan [float]
#  Pi_increase = 0.0 [float]
#  Pi_w_increase = 0.0 [float]
#  Pi_w = 0.0 [float]
#  Pi = 0.0 [float]
#  psi = 0.0 [float]
#  q = 19.757530948461486 [float]
#  Q = 1.0 [float]
#  qB = 1.68 [float]
#  r = 0.012272234429039353 [float]
#  ra = 0.012272234429039353 [float]
#  rk = 0.02552223442903935 [float]
#  rl = -0.003771280245364328 [float]
#  s_w = 0.9425659428720959 [float]
#  s = 0.9425659428720959 [float]
#  tau = 0.25264432895720973 [float]
#  wN = 0.7149076117650649 [float]
#  valuation_res = nan [float]
#  w_res = nan [float]
#  w = 0.7149076117650649 [float]
#  Y = 1.0 [float]
#  Z = 0.5342902579242786 [float]
#  C_hh = 0.707049966505182 [float64]
#  L_hh = 0.9199999996489615 [float64]
#  A_hh = 14.360000000000234 [float64]
#  UCE_hh = 1.3429276433702917 [float64]
#  memory, gb: 0.0
#
# sim:
#  l = ndarray with shape = (100, 1, 7, 100, 100) [dtype: float64]
#  L_hh_from_D = ndarray with shape = (100,) [dtype: float64]
#  a = ndarray with shape = (100, 1, 7, 100, 100) [dtype: float64]
#  A_hh_from_D = ndarray with shape = (100,) [dtype: float64]
#  z_trans = ndarray with shape = (100, 1, 7, 7) [dtype: float64]
#  Dz = ndarray with shape = (100, 1, 7) [dtype: float64]
#  D = ndarray with shape = (100, 1, 7, 100, 100) [dtype: float64]
#  Dbeg = ndarray with shape = (100, 1, 7, 100, 100) [dtype: float64]
#  pol_indices = ndarray with shape = (100, 2, 1, 7, 100, 100) [dtype: int32]
#  pol_weights = ndarray with shape = (100, 2, 1, 7, 100, 100) [dtype: float64]
#  dA = ndarray with shape = (100,) [dtype: float64]
#  dB = ndarray with shape = (100,) [dtype: float64]
#  dclearing_A = ndarray with shape = (100,) [dtype: float64]
#  dclearing_L = ndarray with shape = (100,) [dtype: float64]
#  dclearing_C = ndarray with shape = (100,) [dtype: float64]
#  dclearing_Y = ndarray with shape = (100,) [dtype: float64]
#  dDiv_int = ndarray with shape = (100,) [dtype: float64]
#  dDiv_k = ndarray with shape = (100,) [dtype: float64]
#  dDiv = ndarray with shape = (100,) [dtype: float64]
#  deg = ndarray with shape = (100,) [dtype: float64]
#  dez = ndarray with shape = (100,) [dtype: float64]
#  dem = ndarray with shape = (100,) [dtype: float64]
#  dfisher_res = ndarray with shape = (100,) [dtype: float64]
#  dG = ndarray with shape = (100,) [dtype: float64]
#  di = ndarray with shape = (100,) [dtype: float64]
#  dI = ndarray with shape = (100,) [dtype: float64]
#  dinvest_res = ndarray with shape = (100,) [dtype: float64]
#  dIp = ndarray with shape = (100,) [dtype: float64]
#  dK = ndarray with shape = (100,) [dtype: float64]
#  dL = ndarray with shape = (100,) [dtype: float64]
#  dN = ndarray with shape = (100,) [dtype: float64]
#  dp_eq = ndarray with shape = (100,) [dtype: float64]
#  dp_int = ndarray with shape = (100,) [dtype: float64]
#  dp_k = ndarray with shape = (100,) [dtype: float64]
#  dp_share = ndarray with shape = (100,) [dtype: float64]
#  dPi_increase = ndarray with shape = (100,) [dtype: float64]
#  dPi_w_increase = ndarray with shape = (100,) [dtype: float64]
#  dPi_w = ndarray with shape = (100,) [dtype: float64]
#  dPi = ndarray with shape = (100,) [dtype: float64]
#  dpsi = ndarray with shape = (100,) [dtype: float64]
#  dq = ndarray with shape = (100,) [dtype: float64]
#  dQ = ndarray with shape = (100,) [dtype: float64]
#  dqB = ndarray with shape = (100,) [dtype: float64]
#  dr = ndarray with shape = (100,) [dtype: float64]
#  dra = ndarray with shape = (100,) [dtype: float64]
#  drk = ndarray with shape = (100,) [dtype: float64]
#  drl = ndarray with shape = (100,) [dtype: float64]
#  ds_w = ndarray with shape = (100,) [dtype: float64]
#  ds = ndarray with shape = (100,) [dtype: float64]
#  dtau = ndarray with shape = (100,) [dtype: float64]
#  dwN = ndarray with shape = (100,) [dtype: float64]
#  dvaluation_res = ndarray with shape = (100,) [dtype: float64]
#  dw_res = ndarray with shape = (100,) [dtype: float64]
#  dw = ndarray with shape = (100,) [dtype: float64]
#  dY = ndarray with shape = (100,) [dtype: float64]
#  dZ = ndarray with shape = (100,) [dtype: float64]
#  dC_hh = ndarray with shape = (100,) [dtype: float64]
#  dL_hh = ndarray with shape = (100,) [dtype: float64]
#  dA_hh = ndarray with shape = (100,) [dtype: float64]
#  dUCE_hh = ndarray with shape = (100,) [dtype: float64]
#  memory, gb: 0.4
#
# ss:
#  c = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  l = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  a = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  uce = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  vbeg_l_a = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  z_trans = ndarray with shape = (1, 7, 7) [dtype: float64]
#  Dz = ndarray with shape = (1, 7) [dtype: float64]
#  D = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  Dbeg = ndarray with shape = (1, 7, 100, 100) [dtype: float64]
#  pol_indices = ndarray with shape = (2, 1, 7, 100, 100) [dtype: int32]
#  pol_weights = ndarray with shape = (2, 1, 7, 100, 100) [dtype: float64]
#  A = 14.36 [float]
#  B = 0.08503086769203928 [float]
#  clearing_A = 2.3447910280083306e-13 [float64]
#  clearing_L = -3.510385315763642e-10 [float64]
#  clearing_C = nan [float]
#  clearing_Y = -1.5543122344752192e-15 [float64]
#  Div_int = 0.05743405712790406 [float]
#  Div_k = 0.10946833110703102 [float]
#  Div = 0.1669023882349351 [float]
#  eg = 0.0 [float]
#  ez = 0.0 [float]
#  em = 0.0 [float]
#  fisher_res = nan [float]
#  G = 0.16 [float]
#  i = 0.012272234429039353 [float]
#  I = 0.11818999999999999 [float]
#  invest_res = nan [float]
#  Ip = 0.11818999999999999 [float]
#  K = 8.92 [float]
#  L = 0.92 [float]
#  N = 1.0 [float]
#  p_eq = 13.599999999999993 [float]
#  p_int = 4.679999999999991 [float]
#  p_k = 8.92 [float]
#  p_share = nan [float]
#  Pi_increase = 0.0 [float]
#  Pi_w_increase = 0.0 [float]
#  Pi_w = 0.0 [float]
#  Pi = 0.0 [float]
#  psi = 0.0 [float]
#  q = 19.757530948461486 [float]
#  Q = 1.0 [float]
#  qB = 1.68 [float]
#  r = 0.012272234429039353 [float]
#  ra = 0.012272234429039353 [float]
#  rk = 0.02552223442903935 [float]
#  rl = -0.003771280245364328 [float]
#  s_w = 0.9425659428720959 [float]
#  s = 0.9425659428720959 [float]
#  tau = 0.25264432895720973 [float]
#  wN = 0.7149076117650649 [float]
#  valuation_res = nan [float]
#  w_res = nan [float]
#  w = 0.7149076117650649 [float]
#  Y = 1.0 [float]
#  Z = 0.5342902579242786 [float]
#  C_hh = 0.707049966505182 [float64]
#  L_hh = 0.9199999996489615 [float64]
#  A_hh = 14.360000000000234 [float64]
#  UCE_hh = 1.3429276433702917 [float64]
#  memory, gb: 0.0
#
# path:
#  c = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  l = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  a = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  uce = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  vbeg_l_a = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  z_trans = ndarray with shape = (250, 1, 7, 7) [dtype: float64]
#  Dz = ndarray with shape = (250, 1, 7) [dtype: float64]
#  D = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  Dbeg = ndarray with shape = (250, 1, 7, 100, 100) [dtype: float64]
#  pol_indices = ndarray with shape = (250, 2, 1, 7, 100, 100) [dtype: int32]
#  pol_weights = ndarray with shape = (250, 2, 1, 7, 100, 100) [dtype: float64]
#  A = ndarray with shape = (1250, 250) [dtype: float64]
#  B = ndarray with shape = (1250, 250) [dtype: float64]
#  clearing_A = ndarray with shape = (1250, 250) [dtype: float64]
#  clearing_L = ndarray with shape = (1250, 250) [dtype: float64]
#  clearing_C = ndarray with shape = (1250, 250) [dtype: float64]
#  clearing_Y = ndarray with shape = (1250, 250) [dtype: float64]
#  Div_int = ndarray with shape = (1250, 250) [dtype: float64]
#  Div_k = ndarray with shape = (1250, 250) [dtype: float64]
#  Div = ndarray with shape = (1250, 250) [dtype: float64]
#  eg = ndarray with shape = (1250, 250) [dtype: float64]
#  ez = ndarray with shape = (1250, 250) [dtype: float64]
#  em = ndarray with shape = (1250, 250) [dtype: float64]
#  fisher_res = ndarray with shape = (1250, 250) [dtype: float64]
#  G = ndarray with shape = (1250, 250) [dtype: float64]
#  i = ndarray with shape = (1250, 250) [dtype: float64]
#  I = ndarray with shape = (1250, 250) [dtype: float64]
#  invest_res = ndarray with shape = (1250, 250) [dtype: float64]
#  Ip = ndarray with shape = (1250, 250) [dtype: float64]
#  K = ndarray with shape = (1250, 250) [dtype: float64]
#  L = ndarray with shape = (1250, 250) [dtype: float64]
#  N = ndarray with shape = (1250, 250) [dtype: float64]
#  p_eq = ndarray with shape = (1250, 250) [dtype: float64]
#  p_int = ndarray with shape = (1250, 250) [dtype: float64]
#  p_k = ndarray with shape = (1250, 250) [dtype: float64]
#  p_share = ndarray with shape = (1250, 250) [dtype: float64]
#  Pi_increase = ndarray with shape = (1250, 250) [dtype: float64]
#  Pi_w_increase = ndarray with shape = (1250, 250) [dtype: float64]
#  Pi_w = ndarray with shape = (1250, 250) [dtype: float64]
#  Pi = ndarray with shape = (1250, 250) [dtype: float64]
#  psi = ndarray with shape = (1250, 250) [dtype: float64]
#  q = ndarray with shape = (1250, 250) [dtype: float64]
#  Q = ndarray with shape = (1250, 250) [dtype: float64]
#  qB = ndarray with shape = (1250, 250) [dtype: float64]
#  r = ndarray with shape = (1250, 250) [dtype: float64]
#  ra = ndarray with shape = (1250, 250) [dtype: float64]
#  rk = ndarray with shape = (1250, 250) [dtype: float64]
#  rl = ndarray with shape = (1250, 250) [dtype: float64]
#  s_w = ndarray with shape = (1250, 250) [dtype: float64]
#  s = ndarray with shape = (1250, 250) [dtype: float64]
#  tau = ndarray with shape = (1250, 250) [dtype: float64]
#  wN = ndarray with shape = (1250, 250) [dtype: float64]
#  valuation_res = ndarray with shape = (1250, 250) [dtype: float64]
#  w_res = ndarray with shape = (1250, 250) [dtype: float64]
#  w = ndarray with shape = (1250, 250) [dtype: float64]
#  Y = ndarray with shape = (1250, 250) [dtype: float64]
#  Z = ndarray with shape = (1250, 250) [dtype: float64]
#  C_hh = ndarray with shape = (1250, 250) [dtype: float64]
#  L_hh = ndarray with shape = (1250, 250) [dtype: float64]
#  A_hh = ndarray with shape = (1250, 250) [dtype: float64]
#  UCE_hh = ndarray with shape = (1250, 250) [dtype: float64]
#  memory, gb: 1.5
# _sticky ---------

# %%
models_solved.keys()
# Out:
# dict_keys(['deficit_financing_phi_tau_01', 'deficit_financing_phi_tau_005', 'deficit_financing_phi_tau_001', 'deficit_financing_phi_tau_01_sticky', 'deficit_financing_phi_tau_005_sticky', 'deficit_financing_phi_tau_001_sticky'])

# %%
compare_models = ['deficit_financing_phi_tau_01_sticky', 'deficit_financing_phi_tau_005_sticky', 'deficit_financing_phi_tau_0025']
labels = [f'$\phi_G = 0, \\theta = {baseline_inattention}, \\tau_G = 0.1,$', f'$\phi_G = 0, \\theta = {baseline_inattention}$\\tau_G = 0.05', f'$\phi_G = 0, \\theta = {baseline_inattention}$\\tau_G = 0.025']
models_list = [models_solved[m] for m in compare_models]
models_solved['deficit_financing_phi_tau_01_sticky'].compare_IRFs(models_list, labels, paths, lvl_value=lvl_value, do_shocks=True, do_targets=False, ncols=3, do_linear=True, do_non_linear=False)
# Out:
# ### shocks ###
# ### varnames ###

# %%
for m in compare_models_no_sticky+compare_models:
    get_no_IRF_output(models_solved[m], result=outputs, models_solved=models_solved)
pd.DataFrame.from_dict(outputs).T

# %%
# reset dictionaries to save memory
models = {}
models_solved = {}
model_labels = {}

# %% [markdown]
# # Inattention levels

# %%
models['mixed_f_theta_0935'] = {
    'phi_G': 0.5,
    'inattention': 0.935
}
models['mixed_f_theta_085'] = {
    'phi_G': 0.5,
    'inattention': 0.85
}
models['mixed_f_theta_07'] = {
    'phi_G': 0.5,
    'inattention': 0.7
}
models['mixed_f_theta_1'] = {
    'phi_G': 0.5,
    'inattention': 1.0
}
models['mixed_f_theta_0975'] = {
    'phi_G': 0.5,
    'inattention': 0.975
}
models['mixed_f_theta_0'] = {
    'phi_G': 0.5,
    'inattention': 0.0
}

# %%
compare_models = ['mixed_f_theta_0']
models_solved = solve_model_list(models, compare_models, models_solved)
for m in ['mixed_f_theta_07', 'mixed_f_theta_085', 'mixed_f_theta_0935', 'mixed_f_theta_1', 'mixed_f_theta_0975']:
    models_solved[m] = HANKStickyAnalyticsClass.get_sticky_IRFs(models_solved['mixed_f_theta_0'], inattention=models[m]['inattention'])
# Out:
#  -------- Model: mixed_f_theta_0 ---------
#  -------- Model: mixed_f_theta_07_sticky ---------
#  -------- Model: mixed_f_theta_085_sticky ---------
#  -------- Model: mixed_f_theta_0935_sticky ---------
#  -------- Model: mixed_f_theta_1_sticky ---------
#                   th

# %%
compare_models = ['mixed_f_theta_1', 'mixed_f_theta_0935', 'mixed_f_theta_085', 'mixed_f_theta_07', 'mixed_f_theta_0', 'mixed_f_theta_0975']
labels = [f'$\phi_G = 0.5, \\theta = {1}$', f'$\phi_G = 0.5, \\theta = {0.935}$', f'$\phi_G = 0.5, \\theta = {0.85}$', f'$\phi_G = 0.5, \\theta = {0.7}$', f'$\phi_G = 0.5, \\theta = {0}$', f'$\phi_G = 0.5, \\theta = {0.975}$']
models_list = [models_solved[m] for m in compare_models]
models_solved['mixed_f_theta_0'].compare_IRFs(models_list, labels, paths, lvl_value=lvl_value, do_shocks=True, do_targets=False, ncols=3, do_linear=True, do_non_linear=False)
# Out:
# ### shocks ###
# ### varnames ###

# %%
for m in compare_models:
    get_no_IRF_output(models_solved[m], result=outputs, models_solved=models_solved)
pd.DataFrame.from_dict(outputs).T
# Out:
#                                                                                     MPC  \
# tax_financing                         {'labor': {'annual': 0.432, 'quarterly': 0.336...
# deficit_financing                     {'labor': {'annual': 0.432, 'quarterly': 0.336...
# mixed_financing                       {'labor': {'annual': 0.432, 'quarterly': 0.336...
# tax_financing_sticky                  {'labor': {'annual': 0.432, 'quarterly': 0.336...
# deficit_financing_sticky              {'labor': {'annual': 0.432, 'quarterly': 0.336...
# mixed_financing_sticky                {'labor': {'annual': 0.432, 'quarterly': 0.336...
# deficit_financing_phi_tau_01          {'labor': {'annual': 0.432, 'quarterly': 0.336...
# deficit_financing_phi_tau_005         {'labor': {'annual': 0.432, 'quarterly': 0.336...
# deficit_financing_phi_tau_02          {'labor': {'annual': 0.432, 'quarterly': 0.336...
# deficit_financing_phi_tau_01_sticky   {'labor': {'annual': 0.432, 'quarterly': 0.336...
# deficit_financing_phi_tau_005_sticky  {'labor': {'annual': 0.432, 'quarterly': 0.336...
# deficit_financing_phi_tau_02_sticky   {'labor': {'annual': 0.432, 'quarterly': 0.336...
# mixed_f_theta_1_sticky                {'labor': {'annual': 0.432, 'quarterly': 0.336...
# mixed_f_theta_0935_sticky             {'labor': {'annual': 0.432, 'quarterly': 0.336...
# mixed_f_theta_085_sticky              {'labor': {'annual': 0.432, 'quarterly': 0.336...
# mixed_f_theta_07_sticky               {'labor': {'annual': 0.432, 'quarterly': 0.336...
# mixed_f_theta_0                       {'labor': {'annual': 0.432, 'quarterly': 0.336...
#
#                                                            Fiscal Multiplier  \
# tax_financing                         {'impact': 1.315, 'cumulative': 0.603}
# deficit_financing                      {'impact': 0.851, 'cumulative': 0.56}
# mixed_financing                       {'impact': 1.083, 'cumulative': 0.582}
# tax_financing_sticky                  {'impact': 1.319, 'cumulative': 0.643}
# deficit_financing_sticky              {'impact': 0.876, 'cumulative': 0.583}
# mixed_financing_sticky                {'impact': 1.097, 'cumulative': 0.613}
# deficit_financing_phi_tau_01           {'impact': 0.851, 'cumulative': 0.56}
# deficit_financing_phi_tau_005          {'impact': 0.846, 'cumulative': 0.57}
# deficit_financing_phi_tau_02          {'impact': 0.856, 'cumulative': 0.558}
# deficit_financing_phi_tau_01_sticky   {'impact': 0.876, 'cumulative': 0.583}
# deficit_financing_phi_tau_005_sticky    {'impact': 0.875, 'cumulative': 0.6}
# deficit_financing_phi_tau_02_sticky   {'impact': 0.876, 'cumulative': 0.577}
# mixed_f_theta_1_sticky                {'impact': 1.098, 'cumulative': 0.593}
# mixed_f_theta_0935_sticky             {'impact': 1.097, 'cumulative': 0.613}
# mixed_f_theta_085_sticky              {'impact': 1.096, 'cumulative': 0.608}
# mixed_f_theta_07_sticky               {'impact': 1.094, 'cumulative': 0.597}
# mixed_f_theta_0                       {'impact': 1.083, 'cumulative': 0.582}
#
#                                                        JAC_diff
# tax_financing                         {'abs': nan, 'perc': nan}
# deficit_financing                     {'abs': nan, 'perc': nan}
# mixed_financing                       {'abs': nan, 'perc': nan}
# tax_financing_sticky                  {'abs': nan, 'perc': nan}
# deficit_financing_sticky              {'abs': nan, 'perc': nan}
# mixed_financing_sticky                {'abs': nan, 'perc': nan}
# deficit_financing_phi_tau_01          {'abs': nan, 'perc': nan}
# deficit_financing_phi_tau_005         {'abs': nan, 'perc': nan}
# deficit_financing_phi_tau_02          {'abs': nan, 'perc': nan}
# deficit_financing_phi_tau_01_sticky   {'abs': nan, 'perc': nan}
# deficit_financing_phi_tau_005_sticky  {'abs': nan, 'perc': nan}
# deficit_financing_phi_tau_02_sticky   {'abs': nan, 'perc': nan}
# mixed_f_theta_1_sticky                {'abs': nan, 'perc': nan}
# mixed_f_theta_0935_sticky             {'abs': nan, 'perc': nan}
# mixed_f_theta_085_sticky              {'abs': nan, 'perc': nan}
# mixed_f_theta_07_sticky               {'abs': nan, 'perc': nan}
# mixed_f_theta_0                       {'abs': nan, 'perc': nan}

# %%
# reset dictionaries to save memory
models = {}
models_solved = {}
model_labels = {}
