# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from HANKStickyModel import HANKStickyModelClass

# %%
updated_par = {'phi_G': 0.4,         # mixed financing of fiscal policy shock
                'jump_eg': 0.00,    # government spending shock
                'jump_eg_transfer': 0.01, # transfer shock
                'rho_eg_transfer': 0.9,
                'jump_em': 0.0,
                'beta_mean': 0.998148781410423180382451846526, # 0.99801530464021903644,
                'sigma_e': 0.407581285317861752304224864929, # 0.41634930488891835898,
                'A_L_ratio': 0.930370661686845124016542740719, # 0.929, # 0.92864578790992269308,
                'taylor': 'linear'}
model = HANKStickyModelClass(name='baseline', par={**updated_par ,**{'inattention': 0.0, 'start_dbeg_opti': True}})

# %%
model2 = HANKStickyModelClass(name='baseline')
model2.load()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8968/1667921692.py in <module>
#       1 model2 = HANKStickyModelClass(name='baseline')
# ----> 2 model2.load()
#
# ~\miniconda3\envs\masterthesis\lib\site-packages\EconModel\EconModel.py in load(self, skip)
#     238
#     239         # c. construct
# --> 240         self.from_dict(model_dict)
#     241
#     242     def copy(self,name=None,**kwargs):
#
# ~\miniconda3\envs\masterthesis\lib\site-packages\EconModel\EconModel.py in from_dict(self, model_dict, do_copy)
#     198                             namespace.__dict__[k] = deepcopy(v)
#     199                     else: # full copy
# --> 200                         setattr(self,attr,deepcopy(model_dict[attr]))
#     201                 else:
#     202                     setattr(self,attr,model_dict[attr])
#
# ~\miniconda3\envs\masterthesis\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\masterthesis\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\masterthesis\lib\copy.py in deepcopy(x, memo, _nil)
#     151             copier = getattr(x, "__deepcopy__", None)
#     152             if copier is not None:
# --> 153                 y = copier(memo)
#     154             else:
#     155                 reductor = dispatch_table.get(cls)
#
# MemoryError: Unable to allocate 957. KiB for an array with shape (350, 350) and data type float64

# %%
for key, value in model2.par.__dict__.items():
    model.par.__dict__[key] = value
for key, value in model2.ss.__dict__.items():
    model.ss.__dict__[key] = value

# %%
relevant_settings = {
    'beta': 'beta_mean',
    'T': 'T',
    'MPC target': 'MPC_target',
    'sigma_e': 'sigma_e',
    'A_L_ratio': 'A_L_ratio'
}
for key, value in relevant_settings.items():
    print(f'{key}: {model.par.__dict__[value]:.30f}')
# Out:
# beta: 0.998148781410423180382451846526
# T: 350.000000000000000000000000000000
# MPC target: 0.525000000000000022204460492503
# sigma_e: 0.407581285317861752304224864929
# A_L_ratio: 0.930370675550448278379178645991

# %%
model.find_ss(do_print=True)
# Out:
# Find optimal beta for market clearing
# Traceback (most recent call last):
#   File "C:\Users\Yannik\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\GEModelTools\GEModelClass.py", line 831, in _calc_jac_hh_fakenews
#     self.dpols[(polname, inputname)] = np.zeros(getattr(path, polname).shape)
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 187. MiB for an array with shape (350, 1, 7, 100, 100) and data type float64
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22404/1117553906.py in <module>
# ----> 1 model.find_ss(do_print=True)
#
# ~\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\steady_state.py in find_ss(model, do_print)
#     220
#     221     t0 = time.time()
# --> 222     res = optimize.root(objective_ss, np.array([par.beta_mean, par.sigma_e, par.A_L_ratio]), method='hybr', tol=par.tol_ss, args=(model))   # method: hybr
#     223
#     224     assert res["success"], res["message"]
#
# ~\miniconda3\envs\masterthesis\lib\site-packages\scipy\optimize\_root.py in root(fun, x0, args, method, jac, tol, callback, options)
#     232
#     233     if meth == 'hybr':
# --> 234         sol = _root_hybr(fun, x0, args=args, jac=jac, **options)
#     235     elif meth == 'lm':
#     236         sol = _root_leastsq(fun, x0, args=args, jac=jac, **options)
#
# ~\miniconda3\envs\masterthesis\lib\site-packages\scipy\optimize\_minpack_py.py in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     224     if not isinstance(args, tuple):
#     225         args = (args,)
# --> 226     shape, dtype = _check_func('fsolve', 'func', func, x0, args, n, (n,))
#     227     if epsfcn is None:
#     228         epsfcn = finfo(dtype).eps
#
# ~\miniconda3\envs\masterthesis\lib\site-packages\scipy\optimize\_minpack_py.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      22 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      23                 output_shape=None):
# ---> 24     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      25     if (output_shape is not None) and (shape(res) != output_shape):
#      26         if (output_shape[0] != 1):
#
# ~\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\steady_state.py in objective_ss(x, model, do_print)
#     200     evaluate_ss(model, do_print=do_print)
#     201
# --> 202     model._compute_jac_hh()
#     203
#     204     # MPC_annual = model.jac_hh[('C_hh', 'ez')][0, 0:4].sum()
#
# ~\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\GEModelTools\GEModelClass.py in _compute_jac_hh(self, dx, inputs_hh_all, do_print, do_direct, s_list)
#     968         if not do_direct:
#     969
# --> 970             self._calc_jac_hh_fakenews(dx=dx, inputs_hh_all=inputs_hh_all, do_print=do_print)
#     971
#     972         # b. direct
#
# ~\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\GEModelTools\GEModelClass.py in _calc_jac_hh_fakenews(self, inputs_hh_all, dx, do_print)
#     829
#     830                 for polname in self.outputs_hh:
# --> 831                     self.dpols[(polname, inputname)] = np.zeros(getattr(path, polname).shape)
#     832
#     833                 for s in range(par.T):
#
# MemoryError: Unable to allocate 187. MiB for an array with shape (350, 1, 7, 100, 100) and data type float64

# %%
# model.name = 'low_wealth'
# model.save()

# %%
print(f'beta_grid: {model.par.beta_grid[0]:.20f}')
print(f'sigma_e: {model.par.sigma_e:.20f}')
print(f'par.A_L_ratio: {model.par.A_L_ratio:.20f}')
# Out:
# beta_grid: 0.99814878141042318038
# sigma_e: 0.40758128531786175230
# par.A_L_ratio: 0.93037067555044827838

# %%
print(f'ss.L_hh: {model.ss.L_hh}')
print(f'ss.A_hh: {model.ss.A_hh}')
print(f'hh wealth: {model.ss.A + model.ss.L}')
# Out:
# ss.L_hh: 1.0639362819657632
# ss.A_hh: 14.21606392241102
# hh wealth: 15.279999999999998
# hh wealth: 2.0437678571738616e-07

# %%
print(f'clearing L: {model.ss.clearing_L}')
print(f'clearing L * xi: {model.ss.clearing_L * model.par.xi}')
print(f'clearing wealth: {model.ss.clearing_wealth}')
print(f'clearing Y: {model.ss.clearing_Y}')
print(f'MPC target: {model.ss.MPC_target}')
# Out:
# clearing L: 7.505107646466058e-14
# clearing L * xi: 1.2040830465905748e-15
# clearing wealth: 2.540190280342358e-13
# clearing Y: 1.0769163338864018e-14
# MPC target: -3.731237541160226e-12

# %%
ss = model.ss
par = model.par

# %%
model.par.taylor = 'simple'

# %%
model.compute_jacs(do_print=True)
# Out:
# household Jacobians:
# one step deviation from steady state calculated in 2.8 secs
# curly_Y and curly_D calculated for eg_transfer     in 4.8 secs
# curly_Y and curly_D calculated for ez              in 5.0 secs
# curly_Y and curly_D calculated for ra              in 4.9 secs
# curly_Y and curly_D calculated for rl              in 5.2 secs
# curly_Y and curly_D calculated for tau             in 5.2 secs
# Traceback (most recent call last):
#   File "C:\Users\Yannik\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\GEModelTools\GEModelClass.py", line 831, in _calc_jac_hh_fakenews
#     self.dpols[(polname, inputname)] = np.zeros(getattr(path, polname).shape)
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 187. MiB for an array with shape (350, 1, 7, 100, 100) and data type float64
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23436/28884442.py in <module>
# ----> 1 model.compute_jacs(do_print=True)
#
# ~\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\GEModelTools\GEModelClass.py in compute_jacs(self, dx, skip_hh, inputs_hh_all, skip_shocks, do_print, parallel, do_direct)
#    1164         if not skip_hh and len(self.outputs_hh) > 0:
#    1165             if do_print: print('household Jacobians:')
# -> 1166             self._compute_jac_hh(inputs_hh_all=inputs_hh_all, dx=dx, do_direct=do_direct, do_print=do_print)
#    1167             if self.par.inattention > 0.0:
#    1168                 if do_print:
#
# ~\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\GEModelTools\GEModelClass.py in _compute_jac_hh(self, dx, inputs_hh_all, do_print, do_direct, s_list)
#     968         if not do_direct:
#     969
# --> 970             self._calc_jac_hh_fakenews(dx=dx, inputs_hh_all=inputs_hh_all, do_print=do_print)
#     971
#     972         # b. direct
#
# ~\Meine Ablage\Uni\Master\Master Thesis\Thesis_Code\Hump_Jump_Replication\GEModelTools\GEModelClass.py in _calc_jac_hh_fakenews(self, inputs_hh_all, dx, do_print)
#     829
#     830                 for polname in self.outputs_hh:
# --> 831                     self.dpols[(polname, inputname)] = np.zeros(getattr(path, polname).shape)
#     832
#     833                 for s in range(par.T):
#
# MemoryError: Unable to allocate 187. MiB for an array with shape (350, 1, 7, 100, 100) and data type float64

# %%
print('Annual MPC:')
print(np.sum([model.jac_hh[('C_hh', 'eg_transfer')][i, 0] / (1 + ss.r) ** i for i in range(4)]))
# Out:
# Annual MPC:
# 0.5250000000037313

# %%
model.find_transition_path(do_print=True, do_print_unknowns=False)
# Out:
# finding the transition path:
#  it =   0 -> max. abs. error = 7.29e-03
#    0.00e+00 in fisher_res
#    7.71e-04 in w_res
#    7.29e-03 in clearing_Y
#    0.00e+00 in invest_res
#    0.00e+00 in valuation_res
#  it =   1 -> max. abs. error = 4.57e-03
#    0.00e+00 in fisher_res
#    1.03e-04 in w_res
#    2.47e-03 in clearing_Y
#    4.57e-03 in invest_res
#    3.51e-05 in valuation_res
#  it =   2 -> max. abs. error = 5.23e-04
#    0.00e+00 in fisher_res
#    2.88e-05 in w_res
#    3.64e-04 in clearing_Y
#    5.23e-04 in invest_res
#    2.39e-06 in valuation_res
#  it =   3 -> max. abs. error = 5.58e-05
#    0.00e+00 in fisher_res
#    3.46e-06 in w_res
#    5.58e-05 in clearing_Y
#    4.04e-05 in invest_res
#    2.86e-07 in valuation_res
#  it =   4 -> max. abs. error = 7.76e-06
#    0.00e+00 in fisher_res
#    3.82e-07 in w_res
#    7.76e-06 in clearing_Y
#    6.62e-06 in invest_res
#    2.98e-08 in valuation_res
#  it =   5 -> max. abs. error = 1.05e-06
#    0.00e+00 in fisher_res
#    1.99e-08 in w_res
#    5.61e-07 in clearing_Y
#    1.05e-06 in invest_res
#    3.08e-09 in valuation_res
#  it =   6 -> max. abs. error = 1.93e-07
#    0.00e+00 in fisher_res
#    2.96e-09 in w_res
#    7.78e-08 in clearing_Y
#    1.93e-07 in invest_res
#    2.20e-10 in valuation_res
#  it =   7 -> max. abs. error = 3.70e-08
#    0.00e+00 in fisher_res
#    1.39e-10 in w_res
#    4.48e-09 in clearing_Y
#    3.70e-08 in invest_res
#    3.86e-11 in valuation_res
#  it =   8 -> max. abs. error = 5.85e-09
#    0.00e+00 in fisher_res
#    2.68e-11 in w_res
#    4.98e-10 in clearing_Y
#    5.85e-09 in invest_res
#    4.19e-12 in valuation_res
#  it =   9 -> max. abs. error = 6.81e-10
#    0.00e+00 in fisher_res
#    1.82e-12 in w_res
#    6.11e-11 in clearing_Y
#    6.81e-10 in invest_res
#    4.51e-13 in valuation_res
#  it =  10 -> max. abs. error = 3.96e-11
#    0.00e+00 in fisher_res
#    7.54e-14 in w_res
#    3.18e-12 in clearing_Y
#    3.96e-11 in invest_res
#    1.69e-14 in valuation_res
#  it =  11 -> max. abs. error = 4.63e-12
#    0.00e+00 in fisher_res
#    8.54e-15 in w_res
#    3.92e-13 in clearing_Y
#    4.63e-12 in invest_res
#    1.78e-15 in valuation_res
#
# transition path found in 51.5 secs

# %%
model.find_IRFs()

# %%
models = [model]
labels = ['baseline no sticky',]
paths = ['Y', 'C_hh', 'G', 'I']
paths_short = ['Y', 'C_hh', 'G']
lvl_value = ['eg', 'eg_direct', 'eg_distribution', 'eg_debt', 'eg_transfer', 'ez', 'em',  'r', 'tau', 'rk']
facs = {'r':100}
model.show_IRFs(paths,lvl_value=lvl_value,facs=facs,ncols=3,T_max=model.par.T,do_linear=True,do_shocks=True)
# Out:
# ### shocks ###
# ### varnames ###
# ### tagets ###

# %% [markdown]
# # Misc

# %%
# model.print_unpack_varlist()

# %%
# model.check_non_lin(0)

# %%
# print(np.max(path.A - path.A_hh))
